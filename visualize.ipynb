# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import seaborn as sbn

# %%
df = pd.read_csv("gamedata/data_test_3.csv")
df = df.drop(["Unnamed: 0"], axis=1)
n_data = [1000, 2000, 5000, 10000, 20000, 50000]
x = range(0, 50)

for i in n_data:
    plt.plot(list(df[f"{i}"]), label=f"{i}")
    plt.legend()
    plt.xlabel("epochs")
    plt.ylabel("MSE")
plt.grid()
plt.show()
