# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import seaborn as sbn
import numpy as np

# %%
line = np.linspace(6, 176, 86)
line
plt.plot(line, line, c="green")
plt.plot(line, 500 / line, c="red")
plt.plot(line, line - (500/line), c="black")
plt.plot(line, (line * 1.5) - 90, c="blue")
